# %% [markdown]
# # Notebook 1
# Testing simple brownian motion in 1, 2 and 3 dimensions

# %% [markdown]
# ## 1 Dimension

# %%
import numpy as np
from src.brownian import BrownianMotion

bm = BrownianMotion(num_steps=100, delta_t=0.01)
bm.simulate()
BrownianMotion.plot_brownian_path(bm.positions, title="1D Brownian Motion", show_points=True, point_stride=5)

# %%
import numpy as np
from src.brownian import BrownianMotion

bm = BrownianMotion(num_steps=100, delta_t=0.01)
bm.simulate()
BrownianMotion.plot_brownian_path(bm.positions, title="1D Brownian Motion", mode_1d="time_series", show_points=True, point_stride=5)

# %% [markdown]
# ## 2 Dimensions

# %%
import numpy as np
from src.brownian import BrownianMotion

bm = BrownianMotion(num_steps=100, delta_t=0.01, dimension=2)
bm.simulate()
BrownianMotion.plot_brownian_path(bm.positions, title="2D Brownian Motion", show_points=True, point_stride=5)

# %% [markdown]
# A more complicated example

# %%
import numpy as np
from src.brownian import BrownianMotion

bm = BrownianMotion(num_steps=100, delta_t=0.01, dimension=2, D=0.5, initial_position=np.array([1.0, -1.0]), b=lambda x:x)  # Example drift term
bm.simulate()
BrownianMotion.plot_brownian_path(bm.positions, title="2D Brownian Motion", show_points=True, point_stride=5)

# %% [markdown]
# ## 3 Dimensions

# %%
import numpy as np
from src.brownian import BrownianMotion

bm = BrownianMotion(num_steps=100, delta_t=0.01, dimension=3)
bm.simulate()
BrownianMotion.plot_brownian_path(bm.positions, title="3D Brownian Motion", show_points=True, point_stride=5)

# %% [markdown]
# A more complicated example with some b

# %%
import numpy as np
from src.brownian import BrownianMotion

bm = BrownianMotion(num_steps=100, delta_t=0.01, dimension=3, b=lambda x: 0.1 * x)  # Example drift term
bm.simulate()
BrownianMotion.plot_brownian_path(bm.positions, title="3D Brownian Motion", show_points=True, point_stride=5)
